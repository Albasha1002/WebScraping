# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
r=requests.get('https://keithgalli.github.io/web-scraping/webpage.html')

# %%
soup= bs(r.content)

# %%
soup.find("span")
# Out:
# <span class="txt-blue">
# <a href="https://www.eliteprospects.com/team/10263/mit-mass.-inst.-of-tech./2014-2015?tab=stats"> MIT (Mass. Inst. of Tech.) </a>
# </span>

# %%
print(soup)
# Out:
# <html><head>
# <title>Keith Galli's Page</title>
# <style>
#   table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
# </style>
# </head>
# <body>
# <h1>Welcome to my page!</h1>
# <img src="./images/selfie1.jpg" width="300px"/>
# <h2>About me</h2>
# <p>Hi, my name is Keith and I am a YouTuber who focuses on content related to programming, data science, and machine learning!</p>
# ...

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Keith Galli's Page
#   </title>
#   <style>
#    table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
#   </style>
#  </head>
#  <body>
#   <h1>
#    Welcome to my page!
#   </h1>
#   <img src="./images/selfie1.jpg" width="300px"/>
#   <h2>
#    About me
#   </h2>
#   <p>
# ...

# %%
results=soup.find_all(["h1", "h2"])

# %%
results[0].text
# Out:
# 'Welcome to my page!'

# %%
records=[]
for result in results:
   records.append(result.text[0:])

# %%
records
# Out:
# ['Welcome to my page!',
#  'About me',
#  'Social Media',
#  'Photos',
#  ' Table ',
#  'Mystery Message Challenge!',
#  'Footnotes']

# %%
import pandas as pd

# %%
Heading=pd.DataFrame(records, columns=['H1 command'])

# %%
Heading.to_csv('Heading', index=False)

# %%
paragrap=soup.find_all('p')

# %%
para=[]
for result in paragrap:
  para.append(result.text)

# %%
para
# Out:
# ['Hi, my name is Keith and I am a YouTuber who focuses on content related to programming, data science, and machine learning!',
#  'Here is a link to my channel: youtube.com/kgmit',
#  'I grew up in the great state of New Hampshire here in the USA. From an early age I always loved math. Around my senior year of high school, my brother first introduced me to programming. I found it a creative way to apply the same type of logical thinking skills that I enjoyed with math. This influenced me to study computer science in college and ultimately create a YouTube channel to share some things that I have learned along the way.',
#  "Believe it or not, I don't code 24/7. I love doing all sorts of active things. I like to play ice hockey & table tennis as well as run, hike, skateboard, and snowboard. In addition to sports, I am a board game enthusiast. The two that I've been playing the most recently are Settlers of Catan and Othello.",
# ...

# %%
paragraph=pd.DataFrame(para, columns=['Paragraph'])

# %%
paragraph.to_csv("Paragraph", encoding='utf-8')

# %%
paragraph
# Out:
#                                            Paragraph
# 0  Hi, my name is Keith and I am a YouTuber who f...
# 1    Here is a link to my channel: youtube.com/kgmit
# 2  I grew up in the great state of New Hampshire ...
# 3  Believe it or not, I don't code 24/7. I love d...
# 4  If you scrape the links below grabbing the <p>...
# 5  1. This was actually a minivan that I named De...

# %%
paraId=soup.find_all("p",attrs={"id":"paragrapgh-id"})

# %%
paraId
# Out:
# []

# %%
body=soup.find('body')

# %%
body
# Out:
# <body>
# <h1>Welcome to my page!</h1>
# <img src="./images/selfie1.jpg" width="300px"/>
# <h2>About me</h2>
# <p>Hi, my name is Keith and I am a YouTuber who focuses on content related to programming, data science, and machine learning!</p>
# <p>Here is a link to my channel: <a href="https://www.youtube.com/kgmit">youtube.com/kgmit</a></p>
# <p>I grew up in the great state of New Hampshire here in the USA. From an early age I always loved math. Around my senior year of high school, my brother first introduced me to programming. I found it a creative way to apply the same type of logical thinking skills that I enjoyed with math. This influenced me to study computer science in college and ultimately create a YouTube channel to share some things that I have learned along the way.</p>
# <h3>Hobbies</h3>
# ...

# %%
div=body.find('div')

# %%
div
# Out:
# <div class="row">
# <div class="column">
# <img alt="Lake Como" src="images/italy/lake_como.jpg" style="height:100%"/>
# </div>
# <div class="column">
# <img alt="Pontevecchio, Florence" src="images/italy/pontevecchio.jpg" style="height:100%"/>
# </div>
# <div class="column">
# <img alt="Riomaggiore, Cinque de Terre" src="images/italy/riomaggiore.jpg" style="height:100%"/>
# </div>
# </div>

# %%
header=div.find('h1')

# %%
header
